# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = '/content/drive/MyDrive/GlobalLandTemperaturesByCity[1].csv'

# %%
import pandas as pd
df=pd.read_csv(path)

# %%
df.head(20)

# %%
type(df)

# %%
df.describe

# %%
df_country = df.Country.unique()

# %%
df_city = df.City.unique()

# %%
len(df_country)
# Out:
# 1

# %%
len(df_city)
# Out:
# 1

# %%
df_SriLanka = df.drop('AverageTemperatureUncertainty', axis=1)

# %%
df_SriLanka = df_SriLanka[df_SriLanka.Country == "Sri Lanka"]

# %%
df_SriLanka
# Out:
#               dt  AverageTemperature     City    Country
# 0     1796-01-01              24.317  Colombo  Sri Lanka
# 1     1796-02-01              23.923  Colombo  Sri Lanka
# 2     1796-03-01              24.407  Colombo  Sri Lanka
# 3     1796-04-01              27.171  Colombo  Sri Lanka
# 4     1796-05-01              29.050  Colombo  Sri Lanka
# ...          ...                 ...      ...        ...
# 2608    5/1/2013              29.718  Colombo  Sri Lanka
# 2609    6/1/2013              27.686  Colombo  Sri Lanka
# 2610    7/1/2013              26.519  Colombo  Sri Lanka
# 2611    8/1/2013              26.953  Colombo  Sri Lanka
# 2612    9/1/2013                 NaN  Colombo  Sri Lanka
#
# [2613 rows x 4 columns]

# %%
df_SriLanka = df_SriLanka.drop('Country',axis=1)

# %%
df_SriLanka
# Out:
#               dt  AverageTemperature     City
# 0     1796-01-01              24.317  Colombo
# 1     1796-02-01              23.923  Colombo
# 2     1796-03-01              24.407  Colombo
# 3     1796-04-01              27.171  Colombo
# 4     1796-05-01              29.050  Colombo
# ...          ...                 ...      ...
# 2608    5/1/2013              29.718  Colombo
# 2609    6/1/2013              27.686  Colombo
# 2610    7/1/2013              26.519  Colombo
# 2611    8/1/2013              26.953  Colombo
# 2612    9/1/2013                 NaN  Colombo
#
# [2613 rows x 3 columns]

# %%
df_Colombo = df.drop('AverageTemperatureUncertainty', axis=1)

# %%
df_Colombo = df_SriLanka[df_SriLanka.City == "Colombo"]

# %%
df_Colombo
# Out:
#               dt  AverageTemperature     City
# 0     1796-01-01              24.317  Colombo
# 1     1796-02-01              23.923  Colombo
# 2     1796-03-01              24.407  Colombo
# 3     1796-04-01              27.171  Colombo
# 4     1796-05-01              29.050  Colombo
# ...          ...                 ...      ...
# 2608    5/1/2013              29.718  Colombo
# 2609    6/1/2013              27.686  Colombo
# 2610    7/1/2013              26.519  Colombo
# 2611    8/1/2013              26.953  Colombo
# 2612    9/1/2013                 NaN  Colombo
#
# [2613 rows x 3 columns]

# %%
df_Colombo = df_Colombo.drop('City',axis=1)

# %%
df_Colombo
# Out:
#               dt  AverageTemperature
# 0     1796-01-01              24.317
# 1     1796-02-01              23.923
# 2     1796-03-01              24.407
# 3     1796-04-01              27.171
# 4     1796-05-01              29.050
# ...          ...                 ...
# 2608    5/1/2013              29.718
# 2609    6/1/2013              27.686
# 2610    7/1/2013              26.519
# 2611    8/1/2013              26.953
# 2612    9/1/2013                 NaN
#
# [2613 rows x 2 columns]

# %%
df_Colombo.index = pd.to_datetime(df_Colombo.dt)

# %%
df_Colombo
# Out:
#                     dt  AverageTemperature
# dt
# 1796-01-01  1796-01-01              24.317
# 1796-02-01  1796-02-01              23.923
# 1796-03-01  1796-03-01              24.407
# 1796-04-01  1796-04-01              27.171
# 1796-05-01  1796-05-01              29.050
# ...                ...                 ...
# 2013-05-01    5/1/2013              29.718
# 2013-06-01    6/1/2013              27.686
# 2013-07-01    7/1/2013              26.519
# 2013-08-01    8/1/2013              26.953
# 2013-09-01    9/1/2013                 NaN
#
# [2613 rows x 2 columns]

# %%
df_Colombo = df_Colombo.drop('dt', axis=1)

# %%
df_Colombo
# Out:
#             AverageTemperature
# dt
# 1796-01-01              24.317
# 1796-02-01              23.923
# 1796-03-01              24.407
# 1796-04-01              27.171
# 1796-05-01              29.050
# ...                        ...
# 2013-05-01              29.718
# 2013-06-01              27.686
# 2013-07-01              26.519
# 2013-08-01              26.953
# 2013-09-01                 NaN
#
# [2613 rows x 1 columns]

# %%
# Filter data starting from 1796-01-01
df_Colombo = df_Colombo.loc['1796-01-01':]

# %%
df_Colombo.head()
# Out:
#             AverageTemperature
# dt
# 1796-01-01              24.317
# 1796-02-01              23.923
# 1796-03-01              24.407
# 1796-04-01              27.171
# 1796-05-01              29.050

# %%
# Checking whether there are null values
df_Colombo[df_Colombo.isnull()]
# Out:
#             AverageTemperature
# dt
# 1796-01-01                 NaN
# 1796-02-01                 NaN
# 1796-03-01                 NaN
# 1796-04-01                 NaN
# 1796-05-01                 NaN
# ...                        ...
# 2013-05-01                 NaN
# 2013-06-01                 NaN
# 2013-07-01                 NaN
# 2013-08-01                 NaN
# 2013-09-01                 NaN
#
# [2613 rows x 1 columns]

# %%
len(df_Colombo[df_Colombo.isnull()])
# Out:
# 2613

# %%
df_Colombo = df_Colombo.sort_index()

# %%
df_Colombo.index
# Out:
# DatetimeIndex(['1796-01-01', '1796-02-01', '1796-03-01', '1796-04-01',
#                '1796-05-01', '1796-06-01', '1796-07-01', '1796-08-01',
#                '1796-09-01', '1796-10-01',
#                ...
#                '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01',
#                '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01',
#                '2013-08-01', '2013-09-01'],
#               dtype='datetime64[ns]', name='dt', length=2613, freq=None)

# %%
# Replacing NaN values with the previous effective data
df_Colombo.AverageTemperature.fillna(method='pad', inplace=True)

# %%
df_Colombo[df_Colombo.AverageTemperature.isnull()]
# Out:
# Empty DataFrame
# Columns: [AverageTemperature]
# Index: []

# %%
df_Colombo.describe()
# Out:
#        AverageTemperature
# count          2613.00000
# mean             26.60608
# std               1.59454
# min              21.01000
# 25%              25.48600
# 50%              26.78700
# 75%              27.72500
# max              30.68200

# %%
df_Colombo['Ticks'] = range(0,len(df_Colombo.index.values))

# %%
df_Colombo.head(10)
# Out:
#             AverageTemperature  Ticks
# dt
# 1796-01-01              24.317      0
# 1796-02-01              23.923      1
# 1796-03-01              24.407      2
# 1796-04-01              27.171      3
# 1796-05-01              29.050      4
# 1796-06-01              28.539      5
# 1796-07-01              26.857      6
# 1796-08-01              26.887      7
# 1796-09-01              27.123      8
# 1796-10-01              27.562      9

# %%
df_Colombo.tail(10)
# Out:
#             AverageTemperature  Ticks
# dt
# 2012-12-01              26.828   2603
# 2013-01-01              24.187   2604
# 2013-02-01              25.005   2605
# 2013-03-01              26.301   2606
# 2013-04-01              27.335   2607
# 2013-05-01              29.718   2608
# 2013-06-01              27.686   2609
# 2013-07-01              26.519   2610
# 2013-08-01              26.953   2611
# 2013-09-01              26.953   2612

# %%
# simple plotting for the data
fig = plt.figure(1)
ax1 = fig.add_subplot(111)
ax1.set_xlabel('Ticks')
ax1.set_ylabel('Average Temperature')
ax1.set_title('The Plot')
ax1.plot('Ticks', 'AverageTemperature', data = df_Colombo);

# %%
df_Colombo
# Out:
#             AverageTemperature  Ticks
# dt
# 1796-01-01              24.317      0
# 1796-02-01              23.923      1
# 1796-03-01              24.407      2
# 1796-04-01              27.171      3
# 1796-05-01              29.050      4
# ...                        ...    ...
# 2013-05-01              29.718   2608
# 2013-06-01              27.686   2609
# 2013-07-01              26.519   2610
# 2013-08-01              26.953   2611
# 2013-09-01              26.953   2612
#
# [2613 rows x 2 columns]

# %%
from statsmodels.tsa.stattools import adfuller 
def stationarity_check(ts):
    
    # Determing rolling statistics
    #roll_mean = pd.rolling_mean(ts, window=12)
    roll_mean = ts.rolling(12).mean()
    # Plot rolling statistics:
    plt.plot(ts, color='green',label='Original')
    plt.plot(roll_mean, color='blue', label='Rolling Mean')
    plt.legend(loc='best')
    plt.title('Rolling Mean')
    plt.show(block=False)
    
    # Perform Augmented Dickey-Fuller test:
    print('Augmented Dickey-Fuller test:')
    df_test = adfuller(ts)
    print("type of df_test: ",type(df_test))
    print("df_test: ",df_test)
    df_output = pd.Series(df_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    print("df_output: \n",df_output)
    for key,value in df_test[4].items():
        df_output['Critical Value (%s)'%key] = value
    print(df_output)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
stationarity_check(df_Colombo.AverageTemperature)
# Out:
# Augmented Dickey-Fuller test:
# type of df_test:  <class 'tuple'>
# df_test:  (-4.550471552156974, 0.00015922403226506854, 27, 2585, {'1%': -3.4328822265006687, '5%': -2.862658740388024, '10%': -2.5673655460943023}, 4861.732645713535)
# df_output:
#  Test Statistic                   -4.550472
# p-value                           0.000159
# #Lags Used                       27.000000
# Number of Observations Used    2585.000000
# dtype: float64
# Test Statistic                   -4.550472
# p-value                           0.000159
# #Lags Used                       27.000000
# Number of Observations Used    2585.000000
# Critical Value (1%)              -3.432882
# Critical Value (5%)              -2.862659
# Critical Value (10%)             -2.567366
# dtype: float64

# %%
df_Colombo['Roll_Mean'] = df_Colombo['AverageTemperature'].rolling(12).mean()

# %%
df_Colombo.head(10)
# Out:
#             AverageTemperature  Ticks  Roll_Mean
# dt
# 1796-01-01              24.317      0        NaN
# 1796-02-01              23.923      1        NaN
# 1796-03-01              24.407      2        NaN
# 1796-04-01              27.171      3        NaN
# 1796-05-01              29.050      4        NaN
# 1796-06-01              28.539      5        NaN
# 1796-07-01              26.857      6        NaN
# 1796-08-01              26.887      7        NaN
# 1796-09-01              27.123      8        NaN
# 1796-10-01              27.562      9        NaN

# %%
df_Colombo.head(40)
# Out:
#             AverageTemperature  Ticks  Roll_Mean
# dt
# 1796-01-01              24.317      0        NaN
# 1796-02-01              23.923      1        NaN
# 1796-03-01              24.407      2        NaN
# 1796-04-01              27.171      3        NaN
# 1796-05-01              29.050      4        NaN
# 1796-06-01              28.539      5        NaN
# 1796-07-01              26.857      6        NaN
# 1796-08-01              26.887      7        NaN
# 1796-09-01              27.123      8        NaN
# 1796-10-01              27.562      9        NaN
# 1796-11-01              26.966     10        NaN
# 1796-12-01              23.972     11  26.397833
# 1797-01-01              23.972     12  26.369083
# 1797-02-01              23.972     13  26.373167
# 1797-03-01              24.988     14  26.421583
# 1797-04-01              26.528     15  26.368000
# 1797-05-01              28.488     16  26.321167
# 1797-06-01              29.328     17  26.386917
# ...

# %%
df_Colombo.tail(10)
# Out:
#             AverageTemperature  Ticks  Roll_Mean
# dt
# 2012-12-01              26.828   2603  27.192500
# 2013-01-01              24.187   2604  27.221083
# 2013-02-01              25.005   2605  27.247083
# 2013-03-01              26.301   2606  27.307667
# 2013-04-01              27.335   2607  27.233667
# 2013-05-01              29.718   2608  27.273917
# 2013-06-01              27.686   2609  27.177167
# 2013-07-01              26.519   2610  27.058667
# 2013-08-01              26.953   2611  27.021000
# 2013-09-01              26.953   2612  26.976167

# %%
from statsmodels.graphics.tsaplots import plot_pacf,plot_acf

# %%
plot_acf(df_Colombo.AverageTemperature, lags=50)
plot_pacf(df_Colombo.AverageTemperature, lags=50)
plt.xlabel('lags')
plt.show()

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
import itertools
p = q = range(0, 4)
pq = itertools.product(p, q)
for param in pq:
    try:
        mod = ARMA(df_Colombo.AverageTemperature,order=param)
        results = mod.fit()
        print('ARMA{} - AIC:{}'.format(param, results.aic))
    except:
        continue
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARMA(0, 0) - AIC:9856.745846341442
# ARMA(0, 1) - AIC:8167.577595062026
# ...

# %%
model = ARMA(df_Colombo.AverageTemperature, order=(2,3))  
results_MA = model.fit()  
plt.plot(df_Colombo.AverageTemperature)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('Fitting data _ MSE: %.2f'% (((results_MA.fittedvalues-df_Colombo.AverageTemperature)**2).mean()))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
predictions = results_MA.predict('01/01/1796', '09/01/2014')

# %%
predictions
# Out:
# 1796-01-01    26.607207
# 1796-02-01    25.189069
# 1796-03-01    25.333169
# 1796-04-01    26.150705
# 1796-05-01    28.423344
#                 ...
# 2014-05-01    27.353819
# 2014-06-01    26.795407
# 2014-07-01    26.132827
# 2014-08-01    25.990261
# 2014-09-01    26.434556
# Freq: MS, Length: 2625, dtype: float64

# %%
predictions.tail(12)
# Out:
# 2013-10-01    27.558825
# 2013-11-01    27.696934
# 2013-12-01    26.819631
# 2014-01-01    25.855471
# 2014-02-01    25.704691
# 2014-03-01    26.405231
# 2014-04-01    27.204972
# 2014-05-01    27.353819
# 2014-06-01    26.795407
# 2014-07-01    26.132827
# 2014-08-01    25.990261
# 2014-09-01    26.434556
# Freq: MS, dtype: float64

# %%
df_tempdata = predictions.tail(12)

# %%
plt.plot(predictions.tail(12))

# %%
#df_tempdata.to_json(r'Downloads\TempData.json',orient='split')

# %%
filename = 'TempData.csv'



df_tempdata.to_csv(filename)
